# %% [markdown]
# # Test Notebook
#
# This is a test notebook for Uranus.nvim integration tests.

# %%
# Test cell 1
def hello():
    return "Hello from test notebook"

print(hello())

# %%
# Test cell 2 - variables
x = 42
y = "test string"
z = [1, 2, 3, 4, 5]

# %%
# Test cell 3 - output
import sys
print("stdout output")
print("stderr output", file=sys.stderr)

# %% [markdown]
# ## Another Section
#
# More markdown content here.
