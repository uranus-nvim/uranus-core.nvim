# %%
print('Hello, Uranus!')
# Out:
# 'Hello, Uranus!'

# %%
x = 42print(x)
# Out:
# 42

# %% [markdown]
# # Test Markdown CellThis is a **markdown** cell with *formatting*.

# %%
# This cell has no output yetimport numpy as nparr = np.array([1, 2, 3])arr
